# %% [markdown]
# ## Data Analysis and visualization

# %%
import pandas as pd
pd.__version__
# Out:
# '1.5.3'

# %%
file = pd.read_csv('C:\\Users\\hp\\Data Analysis Labs\\Lab 13\\Sales data.csv')

# %%
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
file.head(5)
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
#
#              Product line  Unit price  Quantity   Tax 5%     Total       Date  \
# 0       Health and beauty       74.69         7  26.1415  548.9715   1/5/2019
# 1  Electronic accessories       15.28         5   3.8200   80.2200   3/8/2019
# 2      Home and lifestyle       46.33         7  16.2155  340.5255   3/3/2019
# 3       Health and beauty       58.22         8  23.2880  489.0480  1/27/2019
# 4       Sports and travel       86.31         7  30.2085  634.3785   2/8/2019
#
#     Time      Payment  cogs (cost of good sales  Rating
# 0  13:08      Ewallet                    522.83     9.1
# ...

# %%
type(file)
# Out:
# pandas.core.frame.DataFrame

# %%
file.shape
# Out:
# (1000, 15)

# %%
file.info
# Out:
# <bound method DataFrame.info of       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%      Total  \
# 0         Health and beauty       74.69         7  26.1415   548.9715
# 1    Electronic accessories       15.28         5   3.8200    80.2200
# ...

# %%
file['Product line']
# Out:
# 0           Health and beauty
# 1      Electronic accessories
# 2          Home and lifestyle
# 3           Health and beauty
# 4           Sports and travel
#                 ...
# 995         Health and beauty
# 996        Home and lifestyle
# 997        Food and beverages
# 998        Home and lifestyle
# 999       Fashion accessories
# Name: Product line, Length: 1000, dtype: object

# %%
file.City
# Out:
# 0         Yangon
# 1      Naypyitaw
# 2         Yangon
# 3         Yangon
# 4         Yangon
#          ...
# 995    Naypyitaw
# 996     Mandalay
# 997       Yangon
# 998       Yangon
# 999       Yangon
# Name: City, Length: 1000, dtype: object

# %%
file[['City','Product line']]
# Out:
#           City            Product line
# 0       Yangon       Health and beauty
# 1    Naypyitaw  Electronic accessories
# 2       Yangon      Home and lifestyle
# 3       Yangon       Health and beauty
# 4       Yangon       Sports and travel
# ..         ...                     ...
# 995  Naypyitaw       Health and beauty
# 996   Mandalay      Home and lifestyle
# 997     Yangon      Food and beverages
# 998     Yangon      Home and lifestyle
# 999     Yangon     Fashion accessories
#
# [1000 rows x 2 columns]

# %%
file.columns
# Out:
# Index(['Invoice ID', 'Branch', 'City', 'Customer type', 'Gender',
#        'Product line', 'Unit price', 'Quantity', 'Tax 5%', 'Total', 'Date',
#        'Time', 'Payment', 'cogs (cost of good sales', 'Rating'],
#       dtype='object')

# %%
file['Product line'].value_counts()
# Out:
# Fashion accessories       178
# Food and beverages        174
# Electronic accessories    170
# Sports and travel         166
# Home and lifestyle        160
# Health and beauty         152
# Name: Product line, dtype: int64

# %%
Pro_grph = file['Product line'].value_counts().plot(kind='bar', figsize=(14,6))

# %%
Pro_grph = file['Product line'].value_counts().plot(kind='line', figsize=(14,6))

# %%
Pro_grph = file['Product line'].value_counts().plot(kind='pie', figsize=(14,6))

# %%
Pro_grph = file['Product line'].value_counts().plot(kind='pie', autopct='%1.2f%%',figsize=(14,6))

# %%
file.groupby(['Product line','Gender'])['Gender'].count()
# Out:
# Product line            Gender
# Electronic accessories  Female    84
#                         Male      86
# Fashion accessories     Female    96
#                         Male      82
# Food and beverages      Female    90
#                         Male      84
# Health and beauty       Female    64
#                         Male      88
# Home and lifestyle      Female    79
#                         Male      81
# Sports and travel       Female    88
#                         Male      78
# Name: Gender, dtype: int64

# %%
file.groupby(['Product line','Gender'])['Gender'].size().unstack().plot(kind='bar',stacked=False,figsize=(14,6))
# Out:
# <Axes: xlabel='Product line'>

# %%
file.groupby(['Product line','Gender'])['Gender'].size().unstack().plot(kind='bar',stacked=True,figsize=(14,6))
# Out:
# <Axes: xlabel='Product line'>

# %%
file.describe()
# Out:
#         Unit price     Quantity       Tax 5%        Total  \
# count  1000.000000  1000.000000  1000.000000  1000.000000
# mean     55.672130     5.510000    15.379369   322.966749
# std      26.494628     2.923431    11.708825   245.885335
# min      10.080000     1.000000     0.508500    10.678500
# 25%      32.875000     3.000000     5.924875   124.422375
# 50%      55.230000     5.000000    12.088000   253.848000
# 75%      77.935000     8.000000    22.445250   471.350250
# max      99.960000    10.000000    49.650000  1042.650000
#
#        cogs (cost of good sales      Rating
# count                1000.00000  1000.00000
# mean                  307.58738     6.97270
# std                   234.17651     1.71858
# min                    10.17000     4.00000
# 25%                   118.49750     5.50000
# 50%                   241.76000     7.00000
# 75%                   448.90500     8.50000
# max                   993.00000    10.00000

# %%
file['Unit price'].describe()
# Out:
# count    1000.000000
# mean       55.672130
# std        26.494628
# min        10.080000
# 25%        32.875000
# 50%        55.230000
# 75%        77.935000
# max        99.960000
# Name: Unit price, dtype: float64

# %%
file['Unit price'].mean()
# Out:
# 55.67213

# %%
file['Unit price'].std()
# Out:
# 26.494628347919768

# %%
file['Unit price'].max()
# Out:
# 99.96

# %%
file[['Gender','Unit price']].groupby(['Gender']).mean()
# Out:
#         Unit price
# Gender
# Female   55.263952
# Male     56.081944

# %%
file[['Gender','Unit price']].groupby(['Gender']).mean().unstack().plot(kind='bar',figsize=(14,6))
# Out:
# <Axes: xlabel='None,Gender'>

# %%
df=file.groupby(['Unit price'])
means=file[['Gender','Unit price']].groupby(['Gender']).mean()
errors=file[['Gender','Unit price']].groupby(['Gender']).std()

fig,file=plt.subplots()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[33], line 2
#       1 # df=file.groupby(['Unit price'])
# ----> 2 means=file[['Gender','Unit price']].groupby(['Gender']).mean()
#       3 errors=file[['Gender','Unit price']].groupby(['Gender']).std()
#       5 fig,file=plt.subplots()
#
# TypeError: 'Axes' object is not subscriptable

# %%
df=file['Unit price'].plot(kind='hist', figsize=(14,6))

df.set_ylabel('Unit Price')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 df=file['Unit price'].plot(kind='hist', figsize=(14,6))
#       3 df.set_ylabel('Unit Price')
#
# TypeError: 'Axes' object is not subscriptable

# %%
file['Unit price'].min()

# %%
file['Unit price'].max()

# %%
file['Unit price'].plot(kind='density', figsize=(14,6), color='red')

# %%
file['Unit price'].plot(kind='box', figsize=(14,6), color='green')

# %%
file['Unit price'].plot(kind='box',vert=False, figsize=(14,6))

# %%
plt.violinplot(file['Unit price'],showmedians=True)

# %%
file[['Unit price','Gender']].boxplot(by='Gender')

# %%
file.plot(kind='scatter', x='City', y='Unit price')

# %%
import seaborn as sb
sb.set(style='darkgrid')
sb.countplot(data=file,x='Gender')

# %%
sb.distplot(file.Total)
